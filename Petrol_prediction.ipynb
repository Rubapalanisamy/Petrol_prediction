# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
df=pd.read_csv('petrol.csv')
df.head()
# Out:
#    YEAR  PRICE
# 0  1989   3.50
# 1  1990   4.08
# 2  1991   5.05
# 3  1992   6.11
# 4  1993   6.67

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['YEAR']],df.PRICE)
# Out:
# LinearRegression()

# %%
# %matplotlib  inline 
plt.xlabel('YEAR')
plt.ylabel('PRICE')
plt.title("Petrol price graph from 1989 to 2023")
plt.scatter(df.YEAR,df.PRICE)
plt.plot(df.YEAR,reg.predict(df[['YEAR']]),color="green")

# %%
import seaborn as sns
sns.regplot(x = "YEAR",y = "PRICE",data = df)
# Out:
# <AxesSubplot: xlabel='YEAR', ylabel='PRICE'>

# %%
a=pd.read_csv('petrol.csv',nrows=10)
plt.title("Petrol price graph from 1989 to 2010")
plt.bar("YEAR", "PRICE", data = a, color = "green")
# Out:
# <BarContainer object of 10 artists>

# %%
a=pd.read_csv('petrol.csv',nrows=23)
plt.title("Petrol price graph from 1989 to 1999")
plt.bar("YEAR", "PRICE", data = a, color = "green")
# Out:
# <BarContainer object of 23 artists>
